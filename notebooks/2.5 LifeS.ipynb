# %%
# %run path.py
from dzdy import *
import matplotlib.pyplot as plt

da = DirectorABM()
da.load_pcore('pBAD', 'scripts/pBAD.txt')
da.load_dcore('scripts/BAD.txt')
# Out:
# PCore pBAD added
# Dcore BAD added

# %%
bad = da.new_abm('BAD', 'pBAD', 'BAD')
## Key command
bad.add_behaviour('BR', 'LifeS', s_death='Dead', s_birth='Young', rate=0.2, cap=400, dt=1)
bad.set_observations(states=['Young', 'Middle', 'Old', 'Alive'], transitions=['Die'])

# %%
a1 = da.generate_abm('BAD')

# %%
out = simulate(a1, {'Young': 100, 'Middle': 100, 'Old': 100}, 0, 100)

# %%
out.plot()
plt.show()

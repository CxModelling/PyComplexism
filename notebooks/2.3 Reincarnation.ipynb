# %%
# %run path.py
from dzdy import *
import matplotlib.pyplot as plt

da = DirectorABM()
da.load_pcore('pBAD', 'scripts/pBAD.txt')
da.load_dcore('scripts/BAD.txt')
# Out:
# PCore pBAD added
# Dcore BAD added

# %%
bad = da.new_abm('BAD', 'pBAD', 'BAD')
## Key command
bad.add_behaviour('Rein', 'Reincarnation', s_death='Dead', s_birth='Young')
bad.set_observations(states=['Young', 'Middle', 'Old', 'Dead'], transitions=['Die'])

# %%
a1 = da.generate_abm('BAD')

# %%
out = simulate(a1, {'Young': 10, 'Middle': 10, 'Old': 10}, 0, 20)

# %%
out.plot()
plt.show()
